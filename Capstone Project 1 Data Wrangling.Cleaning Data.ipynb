# %%
#import basic i/o tools 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read in data file
responses = pd.read_csv('responses.csv')
responses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Columns: 150 entries, Music to House - block of flats
# dtypes: float64(134), int64(5), object(11)
# memory usage: 1.2+ MB

# %%
#review dataset 
responses.head()
# Out:
#    Music  Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# 0    5.0                       3.0    2.0   1.0      2.0              2.0
# 1    4.0                       4.0    2.0   1.0      1.0              1.0
# 2    5.0                       5.0    2.0   2.0      3.0              4.0
# 3    5.0                       3.0    2.0   1.0      1.0              1.0
# 4    5.0                       3.0    4.0   3.0      2.0              4.0
#
#    Musical  Pop  Rock  Metal or Hardrock           ...             Age  \
# 0      1.0  5.0   5.0                1.0           ...            20.0
# 1      2.0  3.0   5.0                4.0           ...            19.0
# 2      5.0  3.0   5.0                3.0           ...            20.0
# 3      1.0  2.0   2.0                1.0           ...            22.0
# 4      3.0  5.0   3.0                1.0           ...            20.0
#
#    Height  Weight  Number of siblings  Gender  Left - right handed  \
# ...

# %%
#find column titles for our data:'I live a very healthy lifestyle.'
responses.columns[[75, 135, 137, 139, 140, 141, 142]]
# Out:
# Index(['Healthy eating', 'Branded clothing', 'Spending on looks',
#        'Spending on healthy eating', 'Age', 'Height', 'Weight'],
#       dtype='object')

# %%
#create dataframe for testing data subset: lifestyle
lifestyle_df = responses[['Healthy eating', 'Branded clothing', 'Spending on looks', 'Spending on healthy eating']]

# %%
#create the dataset of demographics
demographics_df = responses[['Age', 'Height', 'Weight']]

# %%
#get descriptive statistics summary (quantitative factors) of our data of interest
lifestyle_df.describe()
# Out:
#        Healthy eating  Branded clothing  Spending on looks  \
# count     1007.000000       1008.000000        1007.000000
# mean         3.031778          3.050595           3.106256
# std          0.936865          1.306321           1.205368
# min          1.000000          1.000000           1.000000
# 25%          3.000000          2.000000           2.000000
# 50%          3.000000          3.000000           3.000000
# 75%          4.000000          4.000000           4.000000
# max          5.000000          5.000000           5.000000
#
#        Spending on healthy eating
# count                  1008.00000
# mean                      3.55754
# std                       1.09375
# min                       1.00000
# 25%                       3.00000
# 50%                       4.00000
# 75%                       4.00000
# max                       5.00000

# %%
#check descreptive statistics summary 
demographics_df.describe()
# Out:
#                Age      Height      Weight
# count  1003.000000  990.000000  990.000000
# mean     20.433699  173.514141   66.405051
# std       2.828840   10.024505   13.839561
# min      15.000000   62.000000   41.000000
# 25%      19.000000  167.000000   55.000000
# 50%      20.000000  173.000000   64.000000
# 75%      22.000000  180.000000   75.000000
# max      30.000000  203.000000  165.000000

# %%
#look for missing or null values; null values in column = TRUE 
pd.isnull(responses[['Healthy eating', 'Branded clothing', 'Spending on looks', 'Spending on healthy eating', 'Age', 'Height', 'Weight']]).any()
# Out:
# Healthy eating                True
# Branded clothing              True
# Spending on looks             True
# Spending on healthy eating    True
# Age                           True
# Height                        True
# Weight                        True
# dtype: bool

# %%
lifestyle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 4 columns):
# Healthy eating                1007 non-null float64
# Branded clothing              1008 non-null float64
# Spending on looks             1007 non-null float64
# Spending on healthy eating    1008 non-null float64
# dtypes: float64(4)
# memory usage: 31.6 KB

# %%
lifestyle_df.head()
# Out:
#    Healthy eating  Branded clothing  Spending on looks  \
# 0             4.0               5.0                3.0
# 1             3.0               1.0                2.0
# 2             3.0               1.0                3.0
# 3             3.0               3.0                4.0
# 4             4.0               4.0                3.0
#
#    Spending on healthy eating
# 0                         3.0
# 1                         2.0
# 2                         2.0
# 3                         1.0
# 4                         4.0

# %%
#drop missing values 
lifestyle_df.dropna()
# Out:
#       Healthy eating  Branded clothing  Spending on looks  \
# 0                4.0               5.0                3.0
# 1                3.0               1.0                2.0
# 2                3.0               1.0                3.0
# 3                3.0               3.0                4.0
# 4                4.0               4.0                3.0
# 5                2.0               3.0                1.0
# 6                4.0               1.0                4.0
# 7                2.0               4.0                4.0
# 8                1.0               3.0                1.0
# 9                3.0               4.0                3.0
# 10               3.0               2.0                4.0
# 11               3.0               1.0                1.0
# 12               3.0               1.0                3.0
# 13               3.0               2.0                4.0
# 14               1.0               1.0                5.0
# ...

# %%
demographics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 3 columns):
# Age       1003 non-null float64
# Height    990 non-null float64
# Weight    990 non-null float64
# dtypes: float64(3)
# memory usage: 23.8 KB

# %%
demographics_df.head()
# Out:
#     Age  Height  Weight
# 0  20.0   163.0    48.0
# 1  19.0   163.0    58.0
# 2  20.0   176.0    67.0
# 3  22.0   172.0    59.0
# 4  20.0   170.0    59.0

# %%
#dropping missing values
demographics_df.dropna()
# Out:
#        Age  Height  Weight
# 0     20.0   163.0    48.0
# 1     19.0   163.0    58.0
# 2     20.0   176.0    67.0
# 3     22.0   172.0    59.0
# 4     20.0   170.0    59.0
# 5     20.0   186.0    77.0
# 6     20.0   177.0    50.0
# 7     19.0   184.0    90.0
# 8     18.0   166.0    55.0
# 9     19.0   174.0    60.0
# 10    19.0   175.0    60.0
# 11    17.0   176.0    60.0
# 12    24.0   168.0    55.0
# 13    19.0   165.0    55.0
# 14    22.0   175.0    57.0
# 15    18.0   177.0    77.0
# 16    19.0   175.0    65.0
# 17    20.0   168.0    65.0
# 18    18.0   181.0    78.0
# 19    18.0   188.0    90.0
# 20    20.0   186.0    77.0
# 21    24.0   186.0    85.0
# 22    22.0   167.0    70.0
# 23    20.0   168.0    54.0
# 24    19.0   167.0    51.0
# 25    20.0   170.0    56.0
# 26    22.0   165.0    63.0
# 27    19.0   163.0    50.0
# 28    20.0   187.0    80.0
# 29    19.0   168.0    60.0
# ...    ...     ...     ...
# 980   18.0   166.0    53.0
# 981   19.0   168.0    57.0
# ...

# %%
lifestyle_df['Healthy eating'].value_counts(dropna=False)
# Out:
#  3.0    504
#  4.0    239
#  2.0    137
#  1.0     81
#  5.0     46
# NaN       3
# Name: Healthy eating, dtype: int64

# %%
lifestyle_df['Branded clothing'].value_counts(dropna=False)
# Out:
#  3.0    283
#  4.0    240
#  1.0    175
#  5.0    157
#  2.0    153
# NaN       2
# Name: Branded clothing, dtype: int64

# %%
lifestyle_df['Spending on looks'].value_counts(dropna=False)
# Out:
#  3.0    299
#  4.0    247
#  2.0    206
#  5.0    144
#  1.0    111
# NaN       3
# Name: Spending on looks, dtype: int64

# %%
lifestyle_df['Spending on healthy eating'].value_counts(dropna=False)
# Out:
#  4.0    330
#  3.0    282
#  5.0    223
#  2.0    132
#  1.0     41
# NaN       2
# Name: Spending on healthy eating, dtype: int64

# %%
function*list to .valuecounts, combine data, use more variables up against target variable, rename column
